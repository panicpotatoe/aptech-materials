# %%
print("hello 01")
# Out:
# hello 01

# %%
print("hello 02")

# %% [markdown]
# # Heading 1 (run: Shift + Enter)

# %% [markdown]
# ## Heading 1.1

# %% [markdown]
# # Heading 2

# %% [markdown]
# # New Section

# %%
string_a = "hello Python"
string_a_upper = upper(string_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a47f6c9dff10> in <module>()
#       1 string_a = "hello Python"
# ----> 2 string_a_upper = upper(string_a)
#
# NameError: name 'upper' is not defined

# %%
string_a_upper = string_a.upper()
print(string_a_upper)
# Out:
# HELLO PYTHON

# %%
print(type(string_a))
# Out:
# <class 'str'>

# %% [markdown]
# TIỀN trong VÍ
# VÍ trong TÚI
# TÚI là của NHÂN
#
# NHÂN.TÚI.VÍ.TIỀN

# %% [markdown]
# VD 01

# %%
string_01 = 'John'
string_02 = "JOHN"
print(string_01)
print(string_02)
print(type(string_01))
print(type(string_02))
# Out:
# John
# JOHN
# <class 'str'>
# <class 'str'>

# %%
number_01 = 0 #integer
number_02 = -10 #integer
number_03 = 1.00001 #float 1.234, 12.34, 123.4
number_04 = 0b110
print(type(number_01))
print(type(number_02))
print(type(number_03))
print(type(number_04))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
print(number_02 + number_03)
# Out:
# -8.99999

# %%
print(number_04)
# Out:
# 6

# %%
dict_01 = {"name": 'Nhan', 'class': 'DS2106L', 'SS': 13, 'Gender': True}

# %%
file_type = open('drive/MyDrive/test.txt')
print(type(file_type))
# Out:
# <class '_io.TextIOWrapper'>

# %%
array_01 = [1, 'NHAN', -10.5]

# %%
print(array_01[0])
print(array_01[1])
print(array_01[2])
# Out:
# 1
# NHAN
# -10.5

# %%
print(type(array_01[0]))
print(type(array_01[1]))
print(type(array_01[2]))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
tuple_01 = (0, 1, 2, 3)
print(tuple_01[0])
print(tuple_01[3])
# Out:
# 0
# 3

# %%
tuple_02 = (12, 'NHAN', 2.5)

# %%
print(tuple_02[0])
print(tuple_02[1])
print(tuple_02[2])
# Out:
# 12
# NHAN
# 2.5

# %%
# array_01 = [1, 'NHAN', -10.5]
array_01[1] = "HELLO NHAN"
print(array_01)
# Out:
# [1, 'HELLO NHAN', -10.5]

# %%
# tuple_02 = (12, 'NHAN', 2.5)
tuple_02[1] = 'Hello Nhan'
print(tuple_02)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-35a3d7dbb1bf> in <module>()
#       1 # tuple_02 = (12, 'NHAN', 2.5)
# ----> 2 tuple_02[1] = 'Hello Nhan'
#       3 print(tuple_02)
#
# TypeError: 'tuple' object does not support item assignment

# %%
gender = False # male:TRUE, female:FALSE
print(gender)
# Out:
# False

# %% [markdown]
# tạo 1 array, có phần tử vị trí:
# * 0: số 10
# * 1: chữ "Tên của bạn"
# * 2: số -20.5
# * 3: boolean "True"

# %%
print(31.4e+3)
# Out:
# 31400.0

# %%
# True = 1; False = 0
print(True + True)
print(True + False)
print(False * 0)
# Out:
# 2
# 1
# 0

# %%
print(True == True) #True
print(True == False) #False
print(False == False) #True

print(True != True) #Fase
print(True != False) #True
print(False != False) #False

# -1 * -1 => duong
# 1 * 1 => duong
# 1 * -1 => am
# Out:
# True
# False
# True
# False
# True
# False

# %%
a = 3
b = 4
print((a<b) * 10 + (a==b)*20)
# Out:
# 10

# %%
import math
math.sin(72)
# Out:
# 0.25382336276203626

# %%
# print('name:  Nhan')
print('name:\tNhan\nclass:\tDS2106L')
# Out:
# name:	Nhan
# class:	DS2106L

# %%
print('a\tb')
# Out:
# a	b

# %%
print(r'a\tb')
# Out:
# a\tb

# %%
name = 'Nhan'
class_id = 'DS2106L'
# print('my name is: ' + name)
print('my name is: %s \nand I\'m in class: %s' % (name, class_id))
# Out:
# my name is: Nhan
# and I'm in class: DS2106L

# %%
"""
test, comment
test 2
"""

# comment

print('hello world')

print("""
test,  \tcomment \n
test 2
""")
# Out:
# hello world
#
# test,  	comment
#
# test 2

# %%
test_string = 'Hello WorLD'
print(test_string.capitalize()) # <- replace capitalize()
# Out:
# Hello world

# %%
list_01 = [0,1,2]
print(list_01)

list_01.append(5)
print(list_01)
# Out:
# [0, 1, 2]
# [0, 1, 2, 5]

# %%
list_01.insert(2, 10)
print(list_01)
# Out:
# [0, 1, 10, 2, 5]

# %%
print(list_01[1])
print(list_01[2:4])
print(list_01[2:])
print(list_01[:4])
# Out:
# 1
# [10, 2]
# [10, 2, 5]
# [0, 1, 10, 2]

# %%
dict_2 = {'r':'red', 'g':'green', 'y':'yellow'}
print(dict_2)
print(dict_2['g'])
print(dict_2['r'])
# Out:
# {'r': 'red', 'g': 'green', 'y': 'yellow'}
# green
# red

# %%
dict_3 = {}
print(dict_3)

dict_3['1'] = 'mot'
dict_3['2'] = 'hai'
dict_3['3'] = 'ba'

print(dict_3)
# Out:
# {}
# {'1': 'mot', '2': 'hai', '3': 'ba'}

# %%
print(dict_3.keys())
print(dict_3.values())
# Out:
# dict_keys(['1', '2', '3'])
# dict_values(['mot', 'hai', 'ba'])
