# %%
# TODO: import data here

PATH_SALES_DATA = 'https://raw.githubusercontent.com/panicpotatoe/dataset/master/excel_data.csv'
PATH_PRICING_DATA = 'https://raw.githubusercontent.com/panicpotatoe/dataset/master/excel_pricing.csv'

# %% [markdown]
# # Q1
# Format các bảng dữ liệu trông hài hoà hơn

# %%
# TODO: check for invalid character, eg '--' in column `code`

# %% [markdown]
# # Q2
# Lập công thức điền giá trị vào cột `comment` theo quy định sau:
# - Nếu thời gian lưu kho <=30 ghi nhận xét: `good sales`
# - Nếu thời gian lưu kho >90 ghi nhận xét: `bad sales`
# - Còn lại: `normal sales`

# %%
# TODO:
# 1: convert data type to datetime, remember to provide original format
# 2: calculate different days, remember to convert to timedelta with `days` unit
# 3: use pandas.cut() to finish your work, remember to use numpy.inf

# %% [markdown]
# # Q3
# Dựa vào bảng `pricing` để điền thông tin `unit_price`

# %%
# TODO:
# 1: get the code character (2nd character from right-to-left) in column `code`, add to a list
# 2: convert `code list` to `unit price list` using `pricing table data`
# 3: append new column to your dataframe with values in step 2

# %% [markdown]
# # Q4
# Tính `tax` là `10%` nếu mặt hàng ngành xây dựng (`cement`, `brick`, `lime powder`), và `8%` cho các mặt hàng còn lại

# %%
# TODO:
# 1: create a sub dataframe which `product` is in `cement` or `brick` or `lime powder`, assign tax rate
# 2: create a sub dataframe which `product` is NOT in `cement` or `brick` or `lime powder`, assign tax rate
# 3: combine these sub dataframes using pandas.concat()
# 4: calculate tax amount in VND: unit_price x quantity x tax rate

# %% [markdown]
# # Q5
# Tính `sales` = `quantity` * `unit_price` + `tax`

# %%
# TODO: calculate sales amount in VND: unit_price x quantity + tax amount

# %% [markdown]
# # Q6
# Hoàn thành bảng thống kê:
# - tổng số lượng hàng bán được trên mỗi loại sản phẩm
# - tổng thu nhập trên mỗi loại sản phẩm

# %%
# TODO: use pandas.pivot_table()
# you can use pandas.sort_value() for a better arrangement

# %% [markdown]
# # Q7
# Vẽ đồ thị cho bảng thống kê hoàn thành ở **Q6** (đồ thị tự chọn, không bắt buộc)

# %%
# TODO: whatever you want but please don't cry

# %% [markdown]
# # Q8
# Dựa vào đồ thị trên (và có thể vẽ thêm đồ thị khác nếu cần), nhận xét tình hình kinh doanh tại công ty

# %%
# TODO: cry now
