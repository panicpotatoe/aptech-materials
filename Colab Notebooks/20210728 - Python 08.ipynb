# %%
from tkinter import *

# must input this line of code
root = Tk()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-210ac4dd064e> in <module>()
#       2
#       3 # must input this line of code
# ----> 4 root = Tk()
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
# Creating a Label Widget

# Shoving it onto the screen
myLabel1 = Label(root, text = 'Hello World!')
myLabel2 = Label(root, text = 'I love Python <3')
myLabel3 = Label (root, text = ' ')

myLabel1.grid(row=0, column=0)
myLabel2.grid(row=1, column=5)
myLabel3.grid(row=1, column=1)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-49e28217a386> in <module>()
#       2
#       3 # Shoving it onto the screen
# ----> 4 myLabel1 = Label(root, text = 'Hello World!')
#       5 myLabel2 = Label(root, text = 'I love Python <3')
#       6 myLabel3 = Label (root, text = ' ')
#
# NameError: name 'root' is not defined
